# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from cd_diagram import draw_cd_diagram

# %%
df = pd.read_csv("results_rhr_patient.csv")

df['Imputation_Method'] = df['Imputation_Method'].fillna('NoIm')

mechanisms = df['Mechanism'].unique()
mec_labels = {}
for mec in mechanisms:
    if "_" in mec:
        base, sub = mec.split("_", 1)
        mec_labels[mec] = rf"{base}$_{{{sub.upper()}}}$"
    else:
        mec_labels[mec] = mec

metric = "Accuracy"
df_crit= df.groupby(['Mechanism', "Patient", 'MR', 'Imputation_Method'])[metric].mean().reset_index()
df_crit['dataset_name'] = df_crit['Mechanism'] + '_' + df_crit['Patient'] + '_' + df_crit['MR'].astype(str)
df_crit = df_crit.rename(columns={'Imputation_Method': 'classifier_name'})
df_crit = df_crit.rename(columns={metric: 'accuracy'})
df_crit = df_crit.drop(columns=['MR'])
df_crit = df_crit[['classifier_name', 'dataset_name', 'accuracy', 'Mechanism']]
print(df_crit.shape)
# Out:
# (6295, 4)

# %%
dfs = {}

for mec in df_crit['Mechanism'].unique():
    dfs[mec] = df_crit[df_crit['Mechanism'] == mec].drop(columns=['Mechanism'])

for mec, df_mec in dfs.items():
    try:
        draw_cd_diagram(df_perf=df_mec, title=f"{mec_labels[mec]}", labels=False, save_path=f"Plots/CD_Diagrams/CD-AD-{mec}.png")
    except Exception as e:
        print(f"Error processing {mec}: {e}")
# Out:
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Font family 'Arial' not found.
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Font family 'Arial' not found.
# ['HAT' 'HT' 'LR' 'MLP' 'Mean' 'NoIm']
# HAT      7.0
# HT      11.0
# LR      26.0
# MLP     36.0
# Mean    49.0
# NoIm     6.0
# dtype: float64
# NoIm    4.950000
# HAT     4.036667
# HT      3.883333
# LR      2.793333
# MLP     2.680000
# Mean    2.656667
# dtype: float64
# ('Mean', 'NoIm', np.float64(3.025167648515144e-23), True)
# ('MLP', 'NoIm', np.float64(1.5359087866276318e-15), True)
# ('LR', 'NoIm', np.float64(9.589277401742193e-13), True)
# ('HT', 'MLP', np.float64(2.53018671681501e-12), True)
# ('HT', 'LR', np.float64(2.5378653205655038e-11), True)
# ('HAT', 'Mean', np.float64(7.021617930500724e-11), True)
# ('HAT', 'MLP', np.float64(2.9534003186063935e-10), True)
# ('HAT', 'LR', np.float64(4.590779840221136e-10), True)
# ('HT', 'Mean', np.float64(1.157484576989588e-08), True)
# ('HT', 'NoIm', np.float64(5.712801530846763e-06), True)
# ('HAT', 'NoIm', np.float64(2.1768683428517912e-05), True)
# ('LR', 'MLP', np.float64(0.010250323103496087), True)
# ('LR', 'Mean', np.float64(0.015221471496056346), True)
# ('MLP', 'Mean', np.float64(0.4094606123497845), False)
# ('HAT', 'HT', np.float64(0.4154214213001942), False)
# Index(['NoIm', 'HAT', 'HT', 'LR', 'MLP', 'Mean'], dtype='object')
# [1, 2]
# [4, 5]
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Font family 'Arial' not found.
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Font family 'Arial' not found.
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Font family 'Arial' not found.
# ['HAT' 'HT' 'LR' 'MLP' 'Mean' 'NoIm']
# Error processing MAR_l: At least 3 sets of samples must be given for Friedman test, got 1.
# ['HAT' 'HT' 'LR' 'MLP' 'Mean' 'NoIm']
# HAT     34.0
# HT      20.0
# LR      10.0
# MLP     31.0
# Mean     1.0
# NoIm     0.0
# dtype: float64
# NoIm    5.930000
# Mean    4.530000
# MLP     3.073333
# LR      2.793333
# HT      2.570000
# HAT     2.103333
# dtype: float64
# ('HAT', 'NoIm', np.float64(2.2993753426271887e-26), True)
# ('LR', 'NoIm', np.float64(2.2994329438983904e-26), True)
# ('HT', 'NoIm', np.float64(2.2996057560669792e-26), True)
# ('HAT', 'Mean', np.float64(3.5312592580234547e-25), True)
# ('Mean', 'NoIm', np.float64(3.427313598499453e-24), True)
# ('MLP', 'NoIm', np.float64(5.482707143250112e-24), True)
# ('HT', 'Mean', np.float64(7.982497385381537e-23), True)
# ('LR', 'Mean', np.float64(1.419724228605466e-21), True)
# ('MLP', 'Mean', np.float64(3.569104870169858e-14), True)
# ('HAT', 'LR', np.float64(1.8811461125778465e-10), True)
# ('HAT', 'HT', np.float64(1.443682024862749e-05), True)
# ('HAT', 'MLP', np.float64(3.7034845622990405e-05), True)
# ('LR', 'MLP', np.float64(0.03174477600221108), False)
# ('HT', 'MLP', np.float64(0.03804271358764863), False)
# ('HT', 'LR', np.float64(0.07122716290341263), False)
# Index(['NoIm', 'Mean', 'MLP', 'LR', 'HT', 'HAT'], dtype='object')
# [2, 3, 4]
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Font family 'Arial' not found.
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# ['HAT' 'HT' 'LR' 'MLP' 'Mean' 'NoIm']
# HAT     21.0
# HT      27.0
# LR      19.0
# MLP     16.0
# Mean     6.0
# NoIm     0.0
# dtype: float64
# NoIm    5.950000
# Mean    4.240000
# MLP     3.456667
# LR      2.510000
# HAT     2.453333
# HT      2.390000
# dtype: float64
# ('HT', 'NoIm', np.float64(2.346131927480634e-26), True)
# ('LR', 'NoIm', np.float64(2.3461906794110965e-26), True)
# ('HAT', 'NoIm', np.float64(2.3462494327613548e-26), True)
# ('Mean', 'NoIm', np.float64(2.5426449041618666e-26), True)
# ('MLP', 'NoIm', np.float64(4.973766800749532e-26), True)
# ('HT', 'Mean', np.float64(3.767267789680356e-21), True)
# ('HAT', 'Mean', np.float64(9.263025241573492e-20), True)
# ('LR', 'Mean', np.float64(1.067108731068899e-18), True)
# ('HAT', 'MLP', np.float64(4.635768295772247e-09), True)
# ('HT', 'MLP', np.float64(6.484112032815773e-08), True)
# ('MLP', 'Mean', np.float64(1.2292647131461952e-07), True)
# ('LR', 'MLP', np.float64(3.2972049630049057e-07), True)
# ('HT', 'LR', np.float64(0.2508891084475491), False)
# ('HAT', 'LR', np.float64(0.3350938716686014), False)
# ('HAT', 'HT', np.float64(0.539463069651372), False)
# Index(['NoIm', 'Mean', 'MLP', 'LR', 'HAT', 'HT'], dtype='object')
# [3, 4, 5]
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Font family 'Arial' not found.
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Font family 'Arial' not found.
# ['HAT' 'HT' 'LR' 'MLP' 'Mean' 'NoIm']
# HAT     22.0
# HT      14.0
# LR      17.0
# MLP     29.0
# Mean     3.0
# NoIm     0.0
# dtype: float64
# NoIm    5.566667
# Mean    4.590000
# MLP     2.923333
# HT      2.806667
# LR      2.693333
# HAT     2.420000
# dtype: float64
# ('HAT', 'NoIm', np.float64(7.448427985156026e-26), True)
# ('HT', 'NoIm', np.float64(8.561395906219539e-26), True)
# ('MLP', 'NoIm', np.float64(9.038693089626042e-26), True)
# ('LR', 'NoIm', np.float64(1.2057755215534055e-25), True)
# ('HT', 'Mean', np.float64(1.0774021668075091e-21), True)
# ('HAT', 'Mean', np.float64(1.4272088792763273e-21), True)
# ('LR', 'Mean', np.float64(7.528689309615149e-21), True)
# ('MLP', 'Mean', np.float64(2.9147190353061184e-20), True)
# ('Mean', 'NoIm', np.float64(4.324715848201615e-14), True)
# ('HAT', 'HT', np.float64(0.0001412975261706462), True)
# ('HAT', 'MLP', np.float64(0.002312696249578511), True)
# ('HAT', 'LR', np.float64(0.0376229465468253), False)
# ('LR', 'MLP', np.float64(0.07327302922190411), False)
# ('HT', 'MLP', np.float64(0.3656759590069396), False)
# ('HT', 'LR', np.float64(0.38629630251899294), False)
# Index(['NoIm', 'Mean', 'MLP', 'HT', 'LR', 'HAT'], dtype='object')
# [4, 2, 3]
# [4, 5]
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Font family 'Arial' not found.
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Font family 'Arial' not found.
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Font family 'Arial' not found.
# ['HAT' 'HT' 'LR' 'MLP' 'Mean' 'NoIm']
# HAT     23.0
# HT      22.0
# LR      27.0
# MLP     26.0
# Mean     8.0
# NoIm    11.0
# dtype: float64
# Mean    4.986667
# NoIm    4.356667
# MLP     3.180000
# HT      2.913333
# HAT     2.903333
# LR      2.660000
# dtype: float64
# ('HT', 'Mean', np.float64(3.074672447743475e-20), True)
# ('HAT', 'Mean', np.float64(7.721353349401422e-20), True)
# ('MLP', 'Mean', np.float64(2.24604895496019e-19), True)
# ('LR', 'Mean', np.float64(2.7715310228964823e-19), True)
# ('HT', 'NoIm', np.float64(1.1061949432217017e-15), True)
# ('LR', 'NoIm', np.float64(2.159029316278491e-15), True)
# ('HAT', 'NoIm', np.float64(5.854221337953825e-15), True)
# ('MLP', 'NoIm', np.float64(1.2082490335265487e-12), True)
# ('Mean', 'NoIm', np.float64(8.91945531759913e-09), True)
# ('LR', 'MLP', np.float64(0.0001504514037907211), True)
# ('HT', 'LR', np.float64(0.01566639970096418), False)
# ('HT', 'MLP', np.float64(0.01900771441460072), False)
# ('HAT', 'LR', np.float64(0.06284712529408695), False)
# ('HAT', 'MLP', np.float64(0.0851577837871588), False)
# ('HAT', 'HT', np.float64(0.6857047545454936), False)
# Index(['Mean', 'NoIm', 'MLP', 'HT', 'HAT', 'LR'], dtype='object')
# [3, 4, 2]
# [3, 4, 5]
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Font family 'Arial' not found.
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Font family 'Arial' not found.
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Font family 'Arial' not found.
# ['HAT' 'HT' 'LR' 'MLP' 'Mean' 'NoIm']
# HAT     30.0
# HT      15.0
# LR      18.0
# MLP     39.0
# Mean     3.0
# NoIm     7.0
# dtype: float64
# NoIm    5.073333
# Mean    4.850000
# LR      2.860000
# HT      2.820000
# MLP     2.803333
# HAT     2.593333
# dtype: float64
# ('HT', 'NoIm', np.float64(6.573101863808704e-24), True)
# ('HAT', 'NoIm', np.float64(7.581698070516724e-24), True)
# ('MLP', 'NoIm', np.float64(3.754383142143857e-23), True)
# ('LR', 'NoIm', np.float64(6.12750470171843e-22), True)
# ('MLP', 'Mean', np.float64(3.891285180536674e-21), True)
# ('HAT', 'Mean', np.float64(9.434504985435318e-21), True)
# ('HT', 'Mean', np.float64(2.2460483905426847e-19), True)
# ('LR', 'Mean', np.float64(3.4663511156656474e-18), True)
# ('HAT', 'HT', np.float64(0.007998439785747215), False)
# ('HAT', 'LR', np.float64(0.02293538155107945), False)
# ('HT', 'MLP', np.float64(0.37000440632106657), False)
# ('HAT', 'MLP', np.float64(0.4244955786769794), False)
# ('HT', 'LR', np.float64(0.526512959622202), False)
# ('LR', 'MLP', np.float64(0.5693911898851984), False)
# ('Mean', 'NoIm', np.float64(0.8211327831484749), False)
# Index(['NoIm', 'Mean', 'LR', 'HT', 'MLP', 'HAT'], dtype='object')
# [0, 1]
# [2, 3, 4, 5]
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Font family 'Arial' not found.

# %%
from PIL import Image

# List of CD diagram images in order
image_files = [f"Plots/CD_Diagrams/CD-AD-{mec}.png" for mec in mechanisms]

# Open all images
images = [Image.open(img_file) for img_file in image_files]

# Get dimensions
widths, heights = zip(*(img.size for img in images))

# Calculate total height and max width
total_height = sum(heights)
max_width = max(widths)

# Create new image with combined height
combined_image = Image.new('RGB', (max_width, total_height), 'white')

# Paste images one below the other
y_offset = 0
for img in images:
    combined_image.paste(img, (0, y_offset))
    y_offset += img.size[1]

# Save combined image
combined_image.save('Plots/CD_Diagrams/CD-AD-all.png')
print("Combined image saved as CD-AD-all.png")
# Out:
# Combined image saved as CD-AD-all.png
